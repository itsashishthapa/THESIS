# %%
import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np
from gymnasium import spaces
from stable_baselines3 import SAC
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.env_checker import check_env


# ==================== Custom Environment ====================
class Projectile1DEnv(gym.Env):
    """
    Environment for 1D Projectile Motion
    """    
    def __init__(self):
        super().__init__()
        
        # Physics parameters
        self.g = 9.81
        self.max_distance = 100.0
        self.max_angle = 89.0
        self.min_angle = 1.0
        self.max_force = 50.0
        self.min_force = 5.0
        self.tolerance = 0.1 # meters around target for success
        
        
        self.observation_space = spaces.Box(
            low=0.0, high=1.0, shape=(1,), dtype=np.float32
        ) # Normalized target distance(input)
        self.action_space = spaces.Box(
            low=-1.0, high=1.0, shape=(2,), dtype=np.float32
        ) # Normalized angle and force (output)
        
        self.target_distance = 0.0
    
    def reset(self, seed=None, options=None):
        """Reset environment with new random target"""
        super().reset(seed=seed)
        
        self.target_distance = np.random.uniform(10.0, self.max_distance)
        obs = np.array([self.target_distance / self.max_distance], dtype=np.float32)
        
        return obs, {}
    
    def calculate_distance(self, angle_deg, force):
        """Physics: R = (v² * sin(2θ)) / g"""
        angle_rad = np.deg2rad(angle_deg)
        return (force**2 * np.sin(2 * angle_rad)) / self.g
    
    def step(self, action):
        """Execute action and return reward"""
        angle_norm, force_norm = action
        angle = self.min_angle + (angle_norm + 1) / 2 * (self.max_angle - self.min_angle)
        force = self.min_force + (force_norm + 1) / 2 * (self.max_force - self.min_force)
        
        angle = np.clip(angle, self.min_angle, self.max_angle)
        force = np.clip(force, self.min_force, self.max_force)
        
        # Calculate projectile distance
        actual_distance = self.calculate_distance(angle, force)
        error = abs(actual_distance - self.target_distance)
        
        # DENSE REWARD SHAPING - Critical fix!
        # Exponential reward provides gradient even when far from target
        distance_reward = np.exp(-error / 10.0) * 100
        
        # Tiered success bonuses
        if error < self.tolerance:
            success_bonus = 50.0  # Hit the target!
        elif error < 0.5:
            success_bonus = 20.0  # Very close
        elif error < 3.0:
            success_bonus = 5.0   # Close
        else:
            success_bonus = 0.0
        
        # Penalty for very poor performance
        penalty = -5.0 if error > 50.0 else 0.0
        
        reward = float(distance_reward + success_bonus + penalty)
        
        # Episode ends after one shot (single-step MDP)
        terminated = True
        truncated = False
        
        obs = np.array([self.target_distance / self.max_distance], dtype=np.float32)
        info = {
            'angle': float(angle),
            'force': float(force),
            'actual_distance': float(actual_distance),
            'target_distance': float(self.target_distance),
            'error': float(error),
            'success': bool(error < self.tolerance)
        }
        
        return obs, reward, terminated, truncated, info

# %%
# ==================== Callback for Tracking ====================
class TrackingCallback(BaseCallback):
    """
    Callback to track training metrics
    """
    def __init__(self, verbose=0):
        super().__init__(verbose)
        self.episode_rewards = []
        self.episode_errors = []
        self.episode_successes = []
        self.episode_count = 0
    
    def _on_step(self) -> bool:
        # Get info from environment
        for info in self.locals.get('infos', []):
            if 'error' in info:
                self.episode_rewards.append(self.locals['rewards'][0])
                self.episode_errors.append(info['error'])
                self.episode_successes.append(1 if info['success'] else 0)
                self.episode_count += 1
                
                # Print progress every 500 episodes
                if self.episode_count % 500 == 0:
                    avg_reward = np.mean(self.episode_rewards[-500:])
                    avg_error = np.mean(self.episode_errors[-500:])
                    success_rate = np.mean(self.episode_successes[-500:]) * 100
                    print(f"Episode {self.episode_count:5d} | "
                          f"Reward: {avg_reward:7.2f} | "
                          f"Error: {avg_error:6.2f}m | "
                          f"Success: {success_rate:5.1f}%")
        
        return True


# ==================== Training Function ====================
def train_sac_projectile(total_timesteps=50000):
    """
    Train SAC agent on projectile environment
    """
    print("=" * 70)
    print("SAC FOR 1D PROJECTILE MOTION - STABLE-BASELINES3")
    print("=" * 70)
    print()
    
    # Create environment
    env = Projectile1DEnv()
    
    # Verify environment follows Gym interface
    print("Checking environment...")
    check_env(env, warn=True)
    print("✓ Environment check passed!")
    print()
    
    # Create SAC agent with optimized hyperparameters
    print("Creating SAC agent...")
    model = SAC(
        policy="MlpPolicy",
        env=env,
        learning_rate=3e-4,
        buffer_size=100000,
        learning_starts=1000,      # Start learning after 1000 steps
        batch_size=256,
        tau=0.005,                  # Soft update coefficient
        gamma=0,                 # Discount factor
        train_freq=1,               # Update after every step
        gradient_steps=1,
        ent_coef="auto",            # entropy tuning
        target_update_interval=1,
        verbose=0,
        seed=42
    )
    
    print("✓ SAC agent created")
    print("  Policy: MlpPolicy (2-layer 256-unit MLP)")
    print("  Learning rate: 3e-4")
    print("  Batch size: 256")
    print("  Buffer size: 100,000")
    print()
    
    # Create callback for tracking
    callback = TrackingCallback()
    
    # Train the agent
    print(f"Training for {total_timesteps:,} timesteps...")
    print("-" * 70)
    
    model.learn(
        total_timesteps=total_timesteps,
        callback=callback,
        progress_bar=False
    )
    
    print("-" * 70)
    print("Training completed!")
    print()
    
    # Save the model
    model.save("sac_projectile_model")
    print("✓ Model saved as 'sac_projectile_model.zip'")
    
    return model, callback, env


# ==================== Testing Function ====================
def test_agent(model, env, num_tests=100):
    """
    Test trained agent on random targets
    """
    print("\n" + "=" * 70)
    print("TESTING TRAINED AGENT")
    print("=" * 70)
    
    errors = []
    successes = 0
    results = []
    
    for _ in range(num_tests):
        obs, _ = env.reset()
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = env.step(action)
        
        errors.append(info['error'])
        if info['success']:
            successes += 1
        results.append(info)
    
    # Print statistics
    mean_error = np.mean(errors)
    std_error = np.std(errors)
    success_rate = successes / num_tests * 100
    
    print(f"\nTest Results ({num_tests} trials):")
    print(f"  Mean Error: {mean_error:.2f} ± {std_error:.2f}m")
    print(f"  Success Rate: {success_rate:.1f}%")
    print(f"  Min Error: {np.min(errors):.2f}m")
    print(f"  Max Error: {np.max(errors):.2f}m")
    
    # Show some examples
    print("\n" + "-" * 70)
    print("Example Predictions:")
    print(f"{'Target (m)':>12} | {'Angle (°)':>10} | {'Force (m/s)':>12} | "
          f"{'Actual (m)':>11} | {'Error (m)':>10}")
    print("-" * 70)
    
    test_distances = [15, 30, 50, 70, 90]
    for dist in test_distances:
        env.target_distance = dist
        obs = np.array([dist / env.max_distance], dtype=np.float32)
        action, _ = model.predict(obs, deterministic=True)
        _, _, _, _, info = env.step(action)
        
        print(f"{dist:>12.1f} | {info['angle']:>10.1f} | {info['force']:>12.2f} | "
              f"{info['actual_distance']:>11.2f} | {info['error']:>10.2f}")
    
    return {
        'mean_error': mean_error,
        'std_error': std_error,
        'success_rate': success_rate,
        'errors': errors,
        'results': results
    }


# ==================== Visualization ====================
def visualize_results(callback, test_results):
    """
    Create visualization of training and testing results
    """
    fig, axes = plt.subplots(2, 3, figsize=(16, 10))
    
    # Plot 1: Training Rewards
    ax = axes[0, 0]
    rewards = callback.episode_rewards
    window = 100
    smooth = np.convolve(rewards, np.ones(window)/window, mode='valid')
    ax.plot(smooth, linewidth=2, color='blue')
    ax.set_xlabel('Episode')
    ax.set_ylabel('Reward')
    ax.set_title('Training Rewards (100-episode MA)')
    ax.grid(True, alpha=0.3)
    
    # Plot 2: Training Errors
    ax = axes[0, 1]
    errors = callback.episode_errors
    smooth_err = np.convolve(errors, np.ones(window)/window, mode='valid')
    ax.plot(smooth_err, linewidth=2, color='red')
    ax.axhline(y=2.0, color='green', linestyle='--', label='Success Threshold')
    ax.set_xlabel('Episode')
    ax.set_ylabel('Error (m)')
    ax.set_title('Training Errors (100-episode MA)')
    ax.legend()
    ax.grid(True, alpha=0.3)
    
    # Plot 3: Success Rate
    ax = axes[0, 2]
    successes = callback.episode_successes
    success_smooth = np.convolve(successes, np.ones(window)/window, mode='valid') * 100
    ax.plot(success_smooth, linewidth=2, color='green')
    ax.set_xlabel('Episode')
    ax.set_ylabel('Success Rate (%)')
    ax.set_title('Success Rate (100-episode MA)')
    ax.set_ylim([0, 105])
    ax.grid(True, alpha=0.3)
    
    # Plot 4: Test Error Distribution
    ax = axes[1, 0]
    ax.hist(test_results['errors'], bins=30, edgecolor='black', alpha=0.7, color='skyblue')
    ax.axvline(x=2.0, color='red', linestyle='--', linewidth=2, label='Success Threshold')
    ax.set_xlabel('Error (m)')
    ax.set_ylabel('Frequency')
    ax.set_title('Test Error Distribution')
    ax.legend()
    ax.grid(True, alpha=0.3, axis='y')
    
    # Plot 5: Action Distribution
    ax = axes[1, 1]
    angles = [r['angle'] for r in test_results['results']]
    forces = [r['force'] for r in test_results['results']]
    scatter = ax.scatter(angles, forces, c=test_results['errors'], 
                        cmap='RdYlGn_r', s=100, alpha=0.6, edgecolors='black')
    ax.set_xlabel('Angle (°)')
    ax.set_ylabel('Force (m/s)')
    ax.set_title('Learned Actions')
    plt.colorbar(scatter, ax=ax, label='Error (m)')
    ax.grid(True, alpha=0.3)
    
    # Plot 6: Performance Metrics
    ax = axes[1, 2]
    metrics = ['Mean\nError (m)', 'Std\nError (m)', 'Success\nRate (%)']
    values = [test_results['mean_error'], test_results['std_error'], 
              test_results['success_rate']]
    colors = ['coral', 'skyblue', 'lightgreen']
    bars = ax.bar(metrics, values, color=colors, edgecolor='black', alpha=0.7)
    ax.set_ylabel('Value')
    ax.set_title('Test Metrics')
    for bar, val in zip(bars, values):
        height = bar.get_height()
        ax.text(bar.get_x() + bar.get_width()/2., height,
                f'{val:.2f}', ha='center', va='bottom', fontweight='bold')
    ax.grid(True, alpha=0.3, axis='y')
    
    plt.tight_layout()
    plt.savefig('sac_projectile_results_sb3.png', dpi=150, bbox_inches='tight')
    print("\n✓ Visualization saved as 'sac_projectile_results_sb3.png'")
    plt.show()

# %%
# ==================== Main Execution ====================

# Train the agent
model, callback, env = train_sac_projectile(total_timesteps=100000)
# Out:
# ======================================================================
# SAC FOR 1D PROJECTILE MOTION - STABLE-BASELINES3
# ======================================================================
#
# Checking environment...
# ✓ Environment check passed!
#
# Creating SAC agent...
# ✓ SAC agent created
#   Policy: MlpPolicy (2-layer 256-unit MLP)
#   Learning rate: 3e-4
#   Batch size: 256
#   Buffer size: 100,000
#
# Training for 100,000 timesteps...
# ----------------------------------------------------------------------
# Episode   500 | Reward:   10.25 | Error:  50.56m | Success:   0.0%
# Episode  1000 | Reward:    9.55 | Error:  52.65m | Success:   0.0%
# Episode  1500 | Reward:   14.77 | Error:  37.47m | Success:   0.0%
# Episode  2000 | Reward:   66.35 | Error:   5.31m | Success:   0.4%
# Episode  2500 | Reward:   87.58 | Error:   2.23m | Success:   1.2%
# Episode  3000 | Reward:   96.25 | Error:   1.48m | Success:   4.8%
# Episode  3500 | Reward:   98.54 | Error:   1.25m | Success:   4.8%
# Episode  4000 | Reward:  101.36 | Error:   1.11m | Success:   7.6%
# Episode  4500 | Reward:  100.81 | Error:   1.08m | Success:   4.0%
# Episode  5000 | Reward:  103.29 | Error:   0.97m | Success:   6.8%
# Episode  5500 | Reward:  103.39 | Error:   0.92m | Success:   6.8%
# Episode  6000 | Reward:  102.41 | Error:   1.00m | Success:   6.8%
# Episode  6500 | Reward:  102.37 | Error:   0.99m | Success:   6.6%
# Episode  7000 | Reward:  101.33 | Error:   1.09m | Success:   6.8%
# Episode  7500 | Reward:  100.10 | Error:   1.19m | Success:   6.4%
# Episode  8000 | Reward:   99.24 | Error:   1.22m | Success:   4.6%
# Episode  8500 | Reward:   98.59 | Error:   1.33m | Success:   6.8%
# Episode  9000 | Reward:   97.66 | Error:   1.33m | Success:   5.0%
# Episode  9500 | Reward:   94.55 | Error:   1.56m | Success:   3.6%
# Episode 10000 | Reward:   92.81 | Error:   1.72m | Success:   3.2%
# Episode 10500 | Reward:   91.78 | Error:   1.88m | Success:   3.2%
# Episode 11000 | Reward:   90.05 | Error:   2.05m | Success:   3.4%
# Episode 11500 | Reward:   87.75 | Error:   2.21m | Success:   2.2%
# Episode 12000 | Reward:   83.91 | Error:   2.66m | Success:   2.4%
# Episode 12500 | Reward:   82.29 | Error:   2.81m | Success:   2.0%
# Episode 13000 | Reward:   79.92 | Error:   3.21m | Success:   2.6%
# Episode 13500 | Reward:   76.38 | Error:   3.69m | Success:   1.4%
# Episode 14000 | Reward:   74.54 | Error:   3.94m | Success:   1.2%
# Episode 14500 | Reward:   75.73 | Error:   3.75m | Success:   1.6%
# Episode 15000 | Reward:   75.51 | Error:   3.88m | Success:   1.4%
# Episode 15500 | Reward:   74.60 | Error:   4.14m | Success:   3.2%
# Episode 16000 | Reward:   77.08 | Error:   3.64m | Success:   2.0%
# Episode 16500 | Reward:   74.94 | Error:   3.86m | Success:   1.0%
# Episode 17000 | Reward:   76.44 | Error:   3.64m | Success:   1.4%
# Episode 17500 | Reward:   76.44 | Error:   3.75m | Success:   1.6%
# Episode 18000 | Reward:   74.33 | Error:   4.11m | Success:   2.2%
# Episode 18500 | Reward:   76.34 | Error:   3.82m | Success:   1.6%
# Episode 19000 | Reward:   75.23 | Error:   3.94m | Success:   2.0%
# Episode 19500 | Reward:   73.90 | Error:   4.08m | Success:   2.2%
# Episode 20000 | Reward:   77.64 | Error:   3.58m | Success:   2.6%
# Episode 20500 | Reward:   74.77 | Error:   3.99m | Success:   2.4%
# Episode 21000 | Reward:   75.38 | Error:   3.89m | Success:   3.0%
# Episode 21500 | Reward:   74.91 | Error:   3.83m | Success:   1.4%
# Episode 22000 | Reward:   73.75 | Error:   4.19m | Success:   2.2%
# Episode 22500 | Reward:   74.71 | Error:   3.86m | Success:   1.4%
# Episode 23000 | Reward:   76.29 | Error:   3.79m | Success:   2.4%
# Episode 23500 | Reward:   73.67 | Error:   4.03m | Success:   1.2%
# Episode 24000 | Reward:   74.99 | Error:   3.88m | Success:   1.6%
# Episode 24500 | Reward:   76.42 | Error:   3.73m | Success:   2.0%
# Episode 25000 | Reward:   76.52 | Error:   3.73m | Success:   1.0%
# Episode 25500 | Reward:   75.69 | Error:   3.85m | Success:   1.2%
# Episode 26000 | Reward:   74.59 | Error:   4.07m | Success:   1.8%
# Episode 26500 | Reward:   76.30 | Error:   3.78m | Success:   1.6%
# Episode 27000 | Reward:   73.68 | Error:   4.01m | Success:   1.0%
# Episode 27500 | Reward:   73.68 | Error:   4.16m | Success:   1.2%
# Episode 28000 | Reward:   72.90 | Error:   4.17m | Success:   1.4%
# Episode 28500 | Reward:   77.58 | Error:   3.54m | Success:   2.6%
# Episode 29000 | Reward:   74.23 | Error:   3.97m | Success:   1.8%
# Episode 29500 | Reward:   74.91 | Error:   3.84m | Success:   1.2%
# Episode 30000 | Reward:   73.25 | Error:   4.10m | Success:   0.4%
# Episode 30500 | Reward:   76.48 | Error:   3.61m | Success:   1.2%
# Episode 31000 | Reward:   76.01 | Error:   3.79m | Success:   2.4%
# Episode 31500 | Reward:   74.63 | Error:   3.97m | Success:   1.6%
# Episode 32000 | Reward:   74.43 | Error:   4.00m | Success:   1.6%
# Episode 32500 | Reward:   76.27 | Error:   3.86m | Success:   2.6%
# Episode 33000 | Reward:   77.34 | Error:   3.74m | Success:   3.2%
# Episode 33500 | Reward:   75.39 | Error:   3.85m | Success:   1.8%
# Episode 34000 | Reward:   77.33 | Error:   3.54m | Success:   0.8%
# Episode 34500 | Reward:   76.11 | Error:   3.76m | Success:   2.0%
# Episode 35000 | Reward:   74.19 | Error:   4.08m | Success:   1.6%
# Episode 35500 | Reward:   74.89 | Error:   3.86m | Success:   1.6%
# Episode 36000 | Reward:   74.93 | Error:   3.93m | Success:   2.0%
# Episode 36500 | Reward:   75.58 | Error:   3.80m | Success:   1.6%
# Episode 37000 | Reward:   74.14 | Error:   4.01m | Success:   2.0%
# Episode 37500 | Reward:   75.60 | Error:   3.77m | Success:   1.0%
# Episode 38000 | Reward:   74.79 | Error:   3.98m | Success:   1.8%
# Episode 38500 | Reward:   74.58 | Error:   3.89m | Success:   1.8%
# Episode 39000 | Reward:   75.54 | Error:   3.87m | Success:   0.8%
# Episode 39500 | Reward:   75.24 | Error:   3.80m | Success:   2.4%
# Episode 40000 | Reward:   76.45 | Error:   3.65m | Success:   1.6%
# Episode 40500 | Reward:   75.18 | Error:   3.91m | Success:   1.2%
# Episode 41000 | Reward:   75.34 | Error:   3.87m | Success:   1.6%
# Episode 41500 | Reward:   77.10 | Error:   3.65m | Success:   3.0%
# Episode 42000 | Reward:   75.73 | Error:   3.74m | Success:   1.0%
# Episode 42500 | Reward:   75.19 | Error:   3.89m | Success:   2.0%
# Episode 43000 | Reward:   74.85 | Error:   4.05m | Success:   2.4%
# Episode 43500 | Reward:   74.70 | Error:   3.99m | Success:   2.2%
# Episode 44000 | Reward:   75.46 | Error:   3.90m | Success:   2.8%
# Episode 44500 | Reward:   75.25 | Error:   3.91m | Success:   1.8%
# Episode 45000 | Reward:   75.71 | Error:   3.79m | Success:   1.6%
# Episode 45500 | Reward:   74.78 | Error:   3.99m | Success:   1.8%
# Episode 46000 | Reward:   75.69 | Error:   3.70m | Success:   1.8%
# Episode 46500 | Reward:   76.18 | Error:   3.68m | Success:   1.2%
# Episode 47000 | Reward:   75.59 | Error:   3.87m | Success:   2.6%
# Episode 47500 | Reward:   76.89 | Error:   3.67m | Success:   2.2%
# Episode 48000 | Reward:   73.67 | Error:   4.06m | Success:   1.4%
# Episode 48500 | Reward:   74.37 | Error:   4.05m | Success:   2.0%
# Episode 49000 | Reward:   73.61 | Error:   4.13m | Success:   1.8%
# Episode 49500 | Reward:   75.43 | Error:   3.87m | Success:   1.6%
# Episode 50000 | Reward:   76.52 | Error:   3.71m | Success:   2.4%
# Episode 50500 | Reward:   76.06 | Error:   3.82m | Success:   2.8%
# Episode 51000 | Reward:   74.41 | Error:   3.94m | Success:   2.0%
# Episode 51500 | Reward:   76.74 | Error:   3.74m | Success:   1.8%
# Episode 52000 | Reward:   77.01 | Error:   3.60m | Success:   2.2%
# Episode 52500 | Reward:   75.54 | Error:   3.92m | Success:   1.8%
# Episode 53000 | Reward:   74.53 | Error:   4.05m | Success:   1.8%
# Episode 53500 | Reward:   77.12 | Error:   3.60m | Success:   1.8%
# Episode 54000 | Reward:   75.94 | Error:   3.91m | Success:   1.8%
# Episode 54500 | Reward:   76.65 | Error:   3.85m | Success:   2.0%
# Episode 55000 | Reward:   74.84 | Error:   3.99m | Success:   2.6%
# Episode 55500 | Reward:   75.53 | Error:   3.81m | Success:   1.8%
# Episode 56000 | Reward:   73.55 | Error:   4.04m | Success:   1.0%
# Episode 56500 | Reward:   74.85 | Error:   3.87m | Success:   1.4%
# Episode 57000 | Reward:   75.11 | Error:   3.80m | Success:   1.6%
# Episode 57500 | Reward:   75.33 | Error:   3.95m | Success:   1.8%
# Episode 58000 | Reward:   76.11 | Error:   3.69m | Success:   1.6%
# Episode 58500 | Reward:   74.19 | Error:   4.03m | Success:   1.8%
# Episode 59000 | Reward:   76.71 | Error:   3.66m | Success:   1.6%
# Episode 59500 | Reward:   75.13 | Error:   3.97m | Success:   2.2%
# Episode 60000 | Reward:   76.08 | Error:   3.71m | Success:   1.2%
# Episode 60500 | Reward:   74.63 | Error:   3.96m | Success:   0.6%
# Episode 61000 | Reward:   77.20 | Error:   3.69m | Success:   2.8%
# Episode 61500 | Reward:   77.17 | Error:   3.68m | Success:   2.0%
# Episode 62000 | Reward:   75.62 | Error:   3.89m | Success:   2.4%
# Episode 62500 | Reward:   75.15 | Error:   3.95m | Success:   2.4%
# Episode 63000 | Reward:   74.02 | Error:   3.97m | Success:   2.0%
# Episode 63500 | Reward:   75.73 | Error:   3.87m | Success:   2.0%
# Episode 64000 | Reward:   78.17 | Error:   3.43m | Success:   1.6%
# Episode 64500 | Reward:   76.45 | Error:   3.77m | Success:   2.2%
# Episode 65000 | Reward:   77.42 | Error:   3.57m | Success:   2.4%
# Episode 65500 | Reward:   74.54 | Error:   3.85m | Success:   0.8%
# Episode 66000 | Reward:   74.43 | Error:   4.17m | Success:   1.4%
# Episode 66500 | Reward:   75.86 | Error:   3.80m | Success:   1.6%
# Episode 67000 | Reward:   74.82 | Error:   3.93m | Success:   1.0%
# Episode 67500 | Reward:   74.02 | Error:   4.01m | Success:   1.2%
# Episode 68000 | Reward:   75.78 | Error:   3.77m | Success:   1.6%
# Episode 68500 | Reward:   75.56 | Error:   3.76m | Success:   1.6%
# Episode 69000 | Reward:   74.69 | Error:   3.98m | Success:   1.4%
# Episode 69500 | Reward:   76.03 | Error:   3.75m | Success:   2.0%
# Episode 70000 | Reward:   75.77 | Error:   4.00m | Success:   2.6%
# Episode 70500 | Reward:   75.81 | Error:   3.81m | Success:   1.6%
# Episode 71000 | Reward:   75.98 | Error:   3.72m | Success:   1.8%
# Episode 71500 | Reward:   73.90 | Error:   3.96m | Success:   0.6%
# Episode 72000 | Reward:   74.96 | Error:   3.99m | Success:   2.8%
# Episode 72500 | Reward:   75.49 | Error:   3.84m | Success:   1.6%
# Episode 73000 | Reward:   75.97 | Error:   3.79m | Success:   1.8%
# Episode 73500 | Reward:   75.51 | Error:   3.85m | Success:   2.0%
# Episode 74000 | Reward:   75.64 | Error:   3.92m | Success:   2.0%
# Episode 74500 | Reward:   78.12 | Error:   3.45m | Success:   1.6%
# Episode 75000 | Reward:   77.11 | Error:   3.64m | Success:   1.4%
# Episode 75500 | Reward:   74.92 | Error:   3.95m | Success:   2.2%
# Episode 76000 | Reward:   75.90 | Error:   3.79m | Success:   1.2%
# Episode 76500 | Reward:   76.15 | Error:   3.67m | Success:   1.6%
# Episode 77000 | Reward:   75.99 | Error:   3.73m | Success:   1.4%
# Episode 77500 | Reward:   75.80 | Error:   3.80m | Success:   1.4%
# Episode 78000 | Reward:   76.03 | Error:   3.74m | Success:   1.8%
# Episode 78500 | Reward:   74.84 | Error:   3.91m | Success:   1.2%
# Episode 79000 | Reward:   73.21 | Error:   4.17m | Success:   0.4%
# Episode 79500 | Reward:   75.64 | Error:   3.96m | Success:   2.6%
# Episode 80000 | Reward:   74.22 | Error:   3.92m | Success:   1.6%
# Episode 80500 | Reward:   75.82 | Error:   3.78m | Success:   1.2%
# Episode 81000 | Reward:   74.62 | Error:   3.85m | Success:   1.0%
# Episode 81500 | Reward:   76.01 | Error:   3.72m | Success:   1.0%
# Episode 82000 | Reward:   75.73 | Error:   3.80m | Success:   2.0%
# Episode 82500 | Reward:   75.43 | Error:   3.86m | Success:   1.4%
# Episode 83000 | Reward:   76.82 | Error:   3.73m | Success:   1.8%
# Episode 83500 | Reward:   76.44 | Error:   3.70m | Success:   2.8%
# Episode 84000 | Reward:   76.40 | Error:   3.72m | Success:   2.2%
# Episode 84500 | Reward:   74.97 | Error:   3.95m | Success:   2.2%
# Episode 85000 | Reward:   75.43 | Error:   3.83m | Success:   1.6%
# Episode 85500 | Reward:   75.59 | Error:   3.77m | Success:   1.0%
# Episode 86000 | Reward:   74.39 | Error:   3.96m | Success:   1.2%
# Episode 86500 | Reward:   73.50 | Error:   4.00m | Success:   0.8%
# Episode 87000 | Reward:   75.01 | Error:   3.90m | Success:   1.2%
# Episode 87500 | Reward:   76.34 | Error:   3.82m | Success:   2.8%
# Episode 88000 | Reward:   77.93 | Error:   3.62m | Success:   2.6%
# Episode 88500 | Reward:   74.30 | Error:   3.99m | Success:   1.2%
# Episode 89000 | Reward:   75.57 | Error:   3.80m | Success:   1.0%
# Episode 89500 | Reward:   74.30 | Error:   3.95m | Success:   0.8%
# Episode 90000 | Reward:   76.95 | Error:   3.73m | Success:   2.4%
# Episode 90500 | Reward:   76.53 | Error:   3.71m | Success:   1.6%
# Episode 91000 | Reward:   76.19 | Error:   3.78m | Success:   2.6%
# Episode 91500 | Reward:   76.74 | Error:   3.86m | Success:   3.6%
# Episode 92000 | Reward:   75.60 | Error:   3.83m | Success:   1.0%
# Episode 92500 | Reward:   76.27 | Error:   3.80m | Success:   1.2%
# Episode 93000 | Reward:   73.64 | Error:   4.09m | Success:   1.0%
# Episode 93500 | Reward:   75.46 | Error:   3.92m | Success:   1.6%
# Episode 94000 | Reward:   76.58 | Error:   3.66m | Success:   2.2%
# Episode 94500 | Reward:   74.15 | Error:   3.93m | Success:   1.6%
# Episode 95000 | Reward:   76.31 | Error:   3.71m | Success:   2.2%
# Episode 95500 | Reward:   74.49 | Error:   3.94m | Success:   1.2%
# Episode 96000 | Reward:   75.44 | Error:   3.92m | Success:   2.6%
# Episode 96500 | Reward:   76.18 | Error:   3.80m | Success:   1.8%
# Episode 97000 | Reward:   76.05 | Error:   3.90m | Success:   3.0%
# Episode 97500 | Reward:   76.31 | Error:   3.68m | Success:   2.0%
# Episode 98000 | Reward:   75.16 | Error:   3.89m | Success:   1.6%
# Episode 98500 | Reward:   74.40 | Error:   3.95m | Success:   1.4%
# Episode 99000 | Reward:   74.48 | Error:   3.97m | Success:   1.8%
# Episode 99500 | Reward:   76.13 | Error:   3.83m | Success:   2.2%
# Episode 100000 | Reward:   77.28 | Error:   3.55m | Success:   2.0%
# ----------------------------------------------------------------------
# Training completed!
#
# ✓ Model saved as 'sac_projectile_model.zip'

# %%
# Test the agent
test_results = test_agent(model, env, num_tests=1000)

# Visualize results
visualize_results(callback, test_results)
# Out:
# ======================================================================
# TESTING TRAINED AGENT
# ======================================================================
#
# Test Results (1000 trials):
#   Mean Error: 1.29 ± 0.30m
#   Success Rate: 0.0%
#   Min Error: 0.56m
#   Max Error: 1.79m
#
# ----------------------------------------------------------------------
# Example Predictions:
#   Target (m) |  Angle (°) |  Force (m/s) |  Actual (m) |  Error (m)
# ----------------------------------------------------------------------
#         15.0 |       46.0 |        12.36 |       15.56 |       0.56
#         30.0 |       45.7 |        17.56 |       31.42 |       1.42
#         50.0 |       45.4 |        22.40 |       51.13 |       1.13
#         70.0 |       45.1 |        26.48 |       71.47 |       1.47
#         90.0 |       45.0 |        29.96 |       91.51 |       1.51
#
# ✓ Visualization saved as 'sac_projectile_results_sb3.png'

# %%
env = Projectile1DEnv()

model = SAC.load("sac_projectile_model", env=env)
# Test the agent
test_results = test_agent(model, env, num_tests=100000)

print("\n" + "=" * 70)
print("✓ COMPLETE!")
print(f"✓ Final Success Rate: {test_results['success_rate']:.1f}%")
print(f"✓ Final Mean Error: {test_results['mean_error']:.2f}m")
print("=" * 70)
# Out:
# ======================================================================
# TESTING TRAINED AGENT
# ======================================================================
#
# Test Results (100000 trials):
#   Mean Error: 0.50 ± 0.39m
#   Success Rate: 12.6%
#   Min Error: 0.00m
#   Max Error: 2.17m
#
# ----------------------------------------------------------------------
# Example Predictions:
#   Target (m) |  Angle (°) |  Force (m/s) |  Actual (m) |  Error (m)
# ----------------------------------------------------------------------
#         15.0 |       42.5 |        12.53 |       15.95 |       0.95
#         30.0 |       40.7 |        17.35 |       30.34 |       0.34
#         50.0 |       43.3 |        22.01 |       49.28 |       0.72
#         70.0 |       46.1 |        26.07 |       69.25 |       0.75
#         90.0 |       48.6 |        29.81 |       89.90 |       0.10
#
# ======================================================================
# ✓ COMPLETE!
# ✓ Final Success Rate: 12.6%
# ✓ Final Mean Error: 0.50m
# ======================================================================

# %%
env.target_distance=90
obs1=np.array([env.target_distance/env.max_distance],dtype=np.float32)
# obs, _ = env.reset()

# %%
action, _ = model.predict(obs1, deterministic=True)

# %%
action_, _, _, _, info = env.step(action)
        
info
# Out:
# {'angle': 48.57141876220703,
#  'force': 29.812620162963867,
#  'actual_distance': 89.89750671386719,
#  'target_distance': 90.0,
#  'error': 0.1024932861328125,
#  'success': False}

# %%
def plot_current_trajectory(model, env):
    """
    Plot trajectory for the current target in env
    Uses whatever target is already set in env.target_distance
    """
    import matplotlib.pyplot as plt
    import numpy as np
    
    # Use current target distance
    target_dist = env.target_distance
    obs = np.array([target_dist / env.max_distance], dtype=np.float32)
    
    # Get model's prediction
    action, _ = model.predict(obs, deterministic=True)
    _, _, _, _, info = env.step(action)
    
    angle = info['angle']
    force = info['force']
    actual_dist = info['actual_distance']
    error = info['error']
    
    # Calculate trajectory
    angle_rad = np.deg2rad(angle)
    t_flight = (2 * force * np.sin(angle_rad)) / env.g
    t_points = np.linspace(0, t_flight, 100)
    
    x = force * np.cos(angle_rad) * t_points
    y = force * np.sin(angle_rad) * t_points - 0.5 * env.g * t_points**2
    
    # Create plot
    fig, ax = plt.subplots(figsize=(12, 6))
    
    # Plot trajectory
    ax.plot(x, y, 'b-', linewidth=3, label='Trajectory')
    
    # Launch point
    ax.plot(0, 0, 'go', markersize=15, label='Launch Point', zorder=5)
    
    # Landing point
    ax.plot(actual_dist, 0, 'ro', markersize=12, 
            label=f'Landing: {actual_dist:.2f}m', zorder=5)
    
    # Target zone
    target_zone = plt.Rectangle(
        (target_dist - env.tolerance, -1),
        2 * env.tolerance, 
        1,
        color='green', alpha=0.3, label=f'Target Zone'
    )
    ax.add_patch(target_zone)
    ax.axvline(x=target_dist, color='green', linestyle='--', 
               linewidth=2, alpha=0.6, label=f'Target: {target_dist:.2f}m')
    
    # Apex
    # apex_idx = np.argmax(y)
    # ax.plot(x[apex_idx], y[apex_idx], 'y*', markersize=20, 
    #         label=f'Apex: {y[apex_idx]:.2f}m', zorder=5)
    
    # Ground
    ax.axhline(y=0, color='brown', linewidth=3, alpha=0.7)
    
    # Title
    success = "✓ HIT!" if error < env.tolerance else "✗ MISS"
    color = 'green' if error < env.tolerance else 'red'
    ax.set_title(
        f'{success} | Target: {target_dist:.2f}m | Error: {error:.2f}m\n'
        f'Launch Angle: {angle:.2f}° | Launch Velocity: {force:.2f}m/s',
        fontsize=14, fontweight='bold', color=color, pad=20
    )
    
    # Labels
    ax.set_xlabel('Horizontal Distance (m)', fontsize=12)
    ax.set_ylabel('Height (m)', fontsize=12)
    ax.grid(True, alpha=0.3)
    ax.legend(fontsize=11, loc='upper right')
    
    # Limits
    max_x = max(target_dist * 1.1, actual_dist * 1.1)
    ax.set_xlim(-5, max_x)
    ax.set_ylim(-2, np.max(y) * 1.2)
    
    plt.tight_layout()
    plt.savefig('current_trajectory.png', dpi=150, bbox_inches='tight')
    print(f"\n✓ Trajectory plot saved: Target={target_dist:.2f}m, Error={error:.2f}m")
    plt.show()

# %%
plot_current_trajectory(model, env)
# Out:
# ✓ Trajectory plot saved: Target=90.00m, Error=0.10m
